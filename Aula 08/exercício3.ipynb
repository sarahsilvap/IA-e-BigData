# %%
import pandas as pd
import numpy as np #importa a biblioteca numpy
from matplotlib.colors import ListedColormap # biblioteca para alterar cor dos gráficos
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,f1_score # biblioteca para gerar as métricas

# %%
data = pd.read_csv('dadosclientes.csv',sep=',') # importa a base de dados

# %%
data.head(10)
# Out:
#     clientes  Valor_compra  qtde_produtos  forma_pag
# 0  cliente 2           378             10          1
# 1  cliente 5           475             18          1
# 2  cliente 1           285             10          1
# 3  cliente 1           181              4          0
# 4  cliente 7           177             20          1
# 5  cliente 3           320             12          0
# 6  cliente 3           294              5          1
# 7  cliente 6           385              7          1
# 8  cliente 5           257              6          0
# 9  cliente 7            58              2          0

# %%
X = df.iloc[:, [1, 2]].values # x é a entrada onde pega o valor da compra e a qtd de produtos
y = df.iloc[:, -1].values # y é a saida

# %%
X # exibe os valores
# Out:
# array([[378,  10],
#        [475,  18],
#        [285,  10],
#        [181,   4],
#        [177,  20],
#        [320,  12],
#        [294,   5],
#        [385,   7],
#        [257,   6],
#        [ 58,   2],
#        [176,  20],
#        [358,  19],
#        [445,  15],
#        [116,  15],
#        [253,  17],
#        [407,  10],
#        [336,  10],
#        [421,  19],
#        [199,   3],
#        [491,  12],
#        [398,   1],
#        [188,   2],
#        [ 39,   1],
#        [320,  17],
#        [297,   4],
#        [442,  14],
#        [358,  19],
#        [306,  19],
#        [350,   6],
#        [291,   0],
#        [436,  10],
#        [345,  19],
#        [ 22,   9],
#        [260,  13],
#        [182,   1],
#        [ 66,  12],
#        [217,  14],
#        [ 59,   8],
#        [ 79,   1],
#        [371,  19],
#        [181,  13],
#        [291,  17],
#        [357,   2],
#        [ 58,  12],
#        [ 71,  19],
#        [284,  15],
#        [229,  12],
#        [ 18,  11],
#        [281,  18],
#        [ 12,   5],
#        [196,  11],
#        [280,  17],
#        [403,  19],
#        [ 52,  13],
#        [208,  14],
#        [322,  11],
#        [497,   8],
#        [215,   6],
#        [175,   5],
#        [204,  14],
#        [133,  12],
#        [100,   0],
#        [439,  20],
#        [ 39,   5],
#        [204,  17],
#        [280,  13],
#        [402,   5],
#        [142,   4],
#        [398,  14],
#        [472,  10],
#        [421,  19],
#        [ 96,  10],
#        [295,  14],
#        [197,  12],
#        [292,  17],
#        [332,   5],
#        [219,   4],
#        [105,   5],
#        [ 82,   0],
#        [ 91,   5],
#        [ 68,   1],
#        [467,  14],
#        [ 65,   0],
#        [310,  13],
#        [191,   3],
#        [161,   3],
#        [168,   9],
#        [497,  16],
#        [100,  19],
#        [ 45,   1],
#        [ 60,   7],
#        [186,  10],
#        [255,  11],
#        [460,  13],
#        [257,  17],
#        [429,   7],
#        [456,  16],
#        [292,   7],
#        [347,   1],
#        [493,   7],
#        [ 14,  10],
#        [ 45,   6],
#        [ 22,  18],
#        [ 35,   4],
#        [ 42,   2],
#        [ 79,   0],
#        [244,   5],
#        [121,  12],
#        [451,  17],
#        [416,   8],
#        [ 82,   5],
#        [348,   8],
#        [313,   6],
#        [389,  11],
#        [460,   1],
#        [346,  19],
#        [374,   4],
#        [343,   7],
#        [395,  18],
#        [240,  18],
#        [466,  15],
#        [479,  12],
#        [124,  15],
#        [ 95,  19],
#        [487,   6],
#        [258,  12],
#        [182,   5],
#        [181,   0],
#        [ 20,   9],
#        [283,   7],
#        [189,   0],
#        [285,   2],
#        [121,  16],
#        [438,  10],
#        [163,  10],
#        [451,  10],
#        [ 30,   2],
#        [334,   9],
#        [424,   5],
#        [ 78,  14],
#        [227,  11],
#        [393,   5],
#        [121,   9],
#        [243,  10],
#        [184,  16],
#        [155,   7],
#        [120,   9],
#        [436,   5],
#        [282,   8],
#        [103,   1],
#        [298,  10],
#        [183,  13],
#        [281,   9],
#        [305,   4],
#        [367,  18],
#        [237,  16],
#        [ 85,   6],
#        [398,   4],
#        [292,   9],
#        [442,   2],
#        [ 96,  13],
#        [ 96,   8],
#        [216,   8],
#        [166,   0],
#        [395,  16],
#        [419,  15],
#        [327,   4],
#        [205,   8],
#        [340,   6],
#        [172,  13],
#        [195,   7],
#        [258,   2],
#        [ 90,  18],
#        [328,   4],
#        [487,  16],
#        [151,   3],
#        [411,   3],
#        [178,   5],
#        [ 93,   2],
#        [ 98,   4],
#        [395,  10],
#        [ 18,   3],
#        [326,  12],
#        [415,   6],
#        [385,   2],
#        [448,  19],
#        [ 24,   5],
#        [ 27,  18],
#        [329,   1],
#        [374,   7],
#        [498,   9],
#        [170,  12],
#        [ 26,  15],
#        [411,  12],
#        [141,  10],
#        [391,   2],
#        [115,  16],
#        [156,  12],
#        [ 46,  19],
#        [329,  11]])

# %%
X_treino,X_teste, y_treino, y_teste = train_test_split(X,y,test_size=0.3,
                                                       random_state=3)

# %%
sc = StandardScaler() # biblioteca para normalizar os dados

# %%
X_treino = sc.fit_transform(X_treino) # realiza a transformação dos dados
X_teste = sc.fit_transform(X_teste)# realiza a transformação dos dados

# %%
# Cria o algoritmo de machine learning e treinando o algoritmo SVM
algoritmo = SVC(kernel='linear',random_state=3) # Kernel é a equação do modelo svm

# %%
# treinando o modelo
algoritmo.fit(X_treino,y_treino) # treina o modelo com os dados de entrada para cada saida
# Out:
# SVC(kernel='linear', random_state=3)

# %%
# gerando previsão dos resultados
y_prev = algoritmo.predict(X_teste) # realizando a predição dos valores

X_teste
# Out:
# array([[-0.36477659,  0.58249941],
#        [ 0.36798396,  1.27116866],
#        [-1.12714364,  0.75466672],
#        [-0.54981714,  0.4103321 ],
#        [-0.26115389, -0.45050447],
#        [-1.22336472, -1.65567567],
#        [ 1.3672029 , -0.62267178],
#        [-0.00949875,  0.4103321 ],
#        [ 1.41161263,  1.61550329],
#        [-1.60084743,  0.06599747],
#        [-0.9791112 , -0.96700641],
#        [ 0.59003262,  0.58249941],
#        [ 1.56704669,  0.75466672],
#        [ 1.98153751, -0.10616984],
#        [ 1.56704669, -1.31134104],
#        [ 0.72326181, -0.96700641],
#        [ 1.47082561, -0.45050447],
#        [-0.36477659, -0.96700641],
#        [ 0.4494018 ,  1.27116866],
#        [-0.40918632, -0.7948391 ],
#        [ 0.16814017,  1.27116866],
#        [ 0.09412396,  0.06599747],
#        [ 1.58925155,  0.92683404],
#        [ 0.47160667, -0.7948391 ],
#        [ 0.70845856,  0.4103321 ],
#        [-0.99391444, -0.27833716],
#        [-1.5564377 , -0.10616984],
#        [-0.78666903,  0.92683404],
#        [-1.37139715, -0.62267178],
#        [-0.46099768, -0.10616984],
#        [-0.19453929,  1.27116866],
#        [-1.57124094,  0.23816478],
#        [ 0.45680342, -0.10616984],
#        [-0.35737497, -1.48350835],
#        [-1.11974201, -1.48350835],
#        [-0.85328363,  1.09900135],
#        [-0.39438308,  1.78767061],
#        [ 0.47900829,  0.75466672],
#        [-0.65343984, -0.96700641],
#        [-0.55721876, -0.45050447],
#        [-1.07533228, -0.62267178],
#        [ 0.856491  ,  1.61550329],
#        [ 0.04971423,  1.09900135],
#        [ 1.30798993,  0.06599747],
#        [-0.96430796, -1.65567567],
#        [-0.58682525, -1.13917372],
#        [ 1.74468561,  0.92683404],
#        [-0.30556362, -1.65567567],
#        [ 0.66404883,  1.27116866],
#        [ 0.55302451, -0.96700641],
#        [ 0.84908938,  1.61550329],
#        [-1.44541337, -0.96700641],
#        [-1.37139715, -1.48350835],
#        [-0.8088739 ,  1.09900135],
#        [ 1.37460452, -0.27833716],
#        [-0.35737497, -0.7948391 ],
#        [ 1.41161263,  1.61550329],
#        [ 1.52263696,  0.06599747],
#        [-1.01611931, -1.31134104],
#        [-0.10571983, -0.27833716]])

# %%
x_test_padrao = sc.inverse_transform(X_teste)

x_test_padrao
# Out:
# array([[181.,  13.],
#        [280.,  17.],
#        [ 78.,  14.],
#        [156.,  12.],
#        [195.,   7.],
#        [ 65.,   0.],
#        [415.,   6.],
#        [229.,  12.],
#        [421.,  19.],
#        [ 14.,  10.],
#        [ 98.,   4.],
#        [310.,  13.],
#        [442.,  14.],
#        [498.,   9.],
#        [442.,   2.],
#        [328.,   4.],
#        [429.,   7.],
#        [181.,   4.],
#        [291.,  17.],
#        [175.,   5.],
#        [253.,  17.],
#        [243.,  10.],
#        [445.,  15.],
#        [294.,   5.],
#        [326.,  12.],
#        [ 96.,   8.],
#        [ 20.,   9.],
#        [124.,  15.],
#        [ 45.,   6.],
#        [168.,   9.],
#        [204.,  17.],
#        [ 18.,  11.],
#        [292.,   9.],
#        [182.,   1.],
#        [ 79.,   1.],
#        [115.,  16.],
#        [177.,  20.],
#        [295.,  14.],
#        [142.,   4.],
#        [155.,   7.],
#        [ 85.,   6.],
#        [346.,  19.],
#        [237.,  16.],
#        [407.,  10.],
#        [100.,   0.],
#        [151.,   3.],
#        [466.,  15.],
#        [189.,   0.],
#        [320.,  17.],
#        [305.,   4.],
#        [345.,  19.],
#        [ 35.,   4.],
#        [ 45.,   1.],
#        [121.,  16.],
#        [416.,   8.],
#        [182.,   5.],
#        [421.,  19.],
#        [436.,  10.],
#        [ 93.,   2.],
#        [216.,   8.]])

# %%
cm = confusion_matrix(y_teste, y_prev)
print(cm)
# Out:
# [[23 13]
#  [11 13]]

# %%
plt.figure(figsize=(8,6))
print(df.info())
# sns.heatmap(informação a ser exibida, exibir valores, cor, cbar, rotulos dos eixos)
sns.heatmap(cm,annot= True,fmt='d',cmap='Blues',cbar=False,xticklabels=['Crédito','PIX'],yticklabels=['Crédito','PIX'])
plt.xlabel('Previsão')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão - Pagamento no cartão de crédito ou PIX')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clientes       200 non-null    object
#  1   Valor_compra   200 non-null    int64
#  2   qtde_produtos  200 non-null    int64
#  3   forma_pag      200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB
# None

# %%
# acuracia = VP +VN /Total
acc = accuracy_score(y_teste,y_prev)
acc
# Out:
# 0.6

# %%
# precisao = VP / (VP + FN)
prec = precision_score(y_teste,y_prev)
prec
# Out:
# np.float64(0.5)

# %%
f1 = f1_score(y_teste,y_prev)
f1
# Out:
# np.float64(0.52)

# %%
_X, _y = X_treino, y_treino
X1, X2 = np.meshgrid(np.arange(start = _X[:, 0].min() - 1, stop = _X[:, 0].max() + 1, step = 0.01),
                    np.arange(start = _X[:, 1].min() - 1, stop = _X[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, algoritmo.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
            alpha = 0.75, cmap = ListedColormap(('red', 'blue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(_y)):
    plt.scatter(_X[_y == j, 0], _X[_y == j, 1],
                c = ListedColormap(('gray', 'black'))(i), label = j)
plt.title('SVM (Dados de Treinamento)')
plt.xlabel('Valor de compra')
plt.ylabel('Quantidade de produtos')
plt.legend()
plt.show()
# Out:
# C:\Users\s408397\AppData\Local\Temp\ipykernel_25240\543396421.py:9: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(_X[_y == j, 0], _X[_y == j, 1],
