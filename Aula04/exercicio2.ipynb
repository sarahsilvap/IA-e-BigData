# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
Q = np.array([100, 200, 300, 400, 500, 600, 700]).reshape(-1, 1) 
T = np.array([30, 35, 40, 45, 60, 100, 150])

# %%
# Criar e treinar o modelo de regressão linear
modelo = LinearRegression()
modelo.fit(Q, T)
# Out:
# LinearRegression()

# %%
# Fazer previsões com base na quantidade de calor
T_previsto = modelo.predict(Q_teste)

# %%
teste = np.array([5, 2, 7,30,50]).reshape(-1, 1)

# %%
temp_prevista = modelo.predict(teste)

# %%
# Imprimir as previsões
for i in range(len(Q_teste)):
    print(f"Quantidade de calor: {Q_teste[i][0]} - Temperatura prevista: {T_previsto[i]:.2f}")

# Plotar os dados
plt.scatter(Q, T, color='blue', label='Dados de Treinamento')
plt.plot(Q, modelo.predict(Q), color='green', label='Linha de Regressão')
plt.scatter(Q_teste, T_previsto, color='red', label='Dados de Teste')
plt.xlabel('Quantidade de Calor')
plt.ylabel('Temperatura')
plt.title('Relação entre Quantidade de Calor e Temperatura do Forno')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Quantidade de calor: 150 - Temperatura prevista: 20.18
# Quantidade de calor: 250 - Temperatura prevista: 38.39
# Quantidade de calor: 350 - Temperatura prevista: 56.61
# Quantidade de calor: 450 - Temperatura prevista: 74.82
# Quantidade de calor: 550 - Temperatura prevista: 93.04
# Quantidade de calor: 650 - Temperatura prevista: 111.25
# Quantidade de calor: 750 - Temperatura prevista: 129.46
